# %% [markdown]
# <span id="titlepage.xhtml"></span>
#
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" version="1.1" width="100%" height="100%" viewbox="0 0 1200 1600" preserveaspectratio="none">
# <image width="1200" height="1600" xlink:href="cover_image.jpg">
# </svg>
#
# <span id="index.html"></span>
#
# <span class="calibre2">xmuoutje9</span>
#
#
#
# <span class="calibre3">February 4, 2025</span>
#
#
#
# <span class="calibre5">**1 Example 1**</span>
#
# \[ \]: **import pandas as pd**
#
# **import numpy as np**
#
# **import matplotlib.pyplot as plt**
#
#
#
# <span class="calibre3">**1.1**</span>
# <span class="calibre3">**Data**</span>
#
# \[ \]: XX = \[\[100,1,1,1\], \[200, 2,2,1\],\[300,2,2,1\]\]
#
# X = np.array(XX)
#
# \[ \]: X
#
# \[ \]: array(\[\[100, 1, 1, 1\],
#
# \[200, 2, 2, 1\],
#
# \[300, 2, 2, 1\]\])
#
# \[ \]: YY = \[5,10,9\]
#
# Y = np.array(YY)
#
# \[ \]: Y
#
# \[ \]: array(\[ 5, 10, 9\])
#
#
#
# <span class="calibre3">**1.2**</span>
# <span class="calibre3">**Prediction**</span>
#
# \[ \]: theta0 = 1
#
# theta1 = 1
#
# \[ \]: yhat1 = (theta0 + (theta1\*X\[0\]\[0\]))
#
# yhat2 = (theta0 + (theta1\*X\[1\]\[0\]))
#
# yhat3 = (theta0 + (theta1\*X\[2\]\[0\]))
#
# yhat = \[yhat1, yhat2, yhat3\]
#
# yhat
#
# \[ \]: \[101, 201, 301\]
#
#
#
# 1
#
# <span class="calibre3">**1.3**</span>
# <span class="calibre3">**Error**</span>
#
# \[ \]: Error1 = yhat1-Y\[0\]
#
# Error2 = yhat2-Y\[1\]
#
# Error3 = yhat3-Y\[2\]
#
# Errors = \[Error1, Error2, Error3\]
#
# Errors
#
# \[ \]: \[96, 191, 292\]
#
# \[ \]: Errormean = sum(map(**lambda** x: x \*\* 2, Errors)) /
# len(Errors)
#
# Errormean
#
# \[ \]: 43653.666666666664
#
#
#
# <span class="calibre3">**1.4**</span>
# <span class="calibre3">**Plot**</span>
#
# **1.4.1** <span class="calibre11">**theta0 = 0, theta1 = 1 (Intercept =
# 0 and slope = 1)**</span>
#
# \[ \]: theta0 = 0
#
# theta1 = 1
#
# yhat1 = (theta0 + (theta1\*X\[0\]\[0\]))
#
# yhat2 = (theta0 + (theta1\*X\[1\]\[0\]))
#
# yhat3 = (theta0 + (theta1\*X\[2\]\[0\]))
#
# yhat = \[yhat1, yhat2, yhat3\]
#
# yhat
#
# \[ \]: \[100, 200, 300\]
#
# \[ \]: plt.figure(figsize=(5, 5))
#
# plt.grid(color=‘k’, linestyle=’-‘, linewidth=0.5)
#
# plt.scatter(X\[:,0\], Y, color=‘blue’)
#
# plt.plot(X\[:,0\], yhat, ‘-r’)
#
# plt.xlabel(“size”)
#
# plt.ylabel(“price”)
#
# \[ \]: Text(0, 0.5, ‘price’)
#
#
#
# 2
#
# <span class="calibre3">**1.5**</span> <span class="calibre3">**theta0 =
# 1, theta1 = 0**</span>
#
# \[ \]: theta0 = 1
#
# theta1 = 0
#
# yhat1 = (theta0 + (theta1\*X\[0\]\[0\]))
#
# yhat2 = (theta0 + (theta1\*X\[1\]\[0\]))
#
# yhat3 = (theta0 + (theta1\*X\[2\]\[0\]))
#
# yhat = \[yhat1, yhat2, yhat3\]
#
# yhat
#
# \[ \]: \[1, 1, 1\]
#
# \[ \]: plt.figure(figsize=(5, 5))
#
# plt.grid(color=‘k’, linestyle=’-‘, linewidth=0.5)
#
# plt.scatter(X\[:,0\], Y, color=‘blue’)
#
# plt.plot(X\[:,0\], yhat, ‘-r’)
#
# plt.xlabel(“size”)
#
# plt.ylabel(“price”)
#
#
#
# 3
#
# \[ \]: Text(0, 0.5, ‘price’)
#
#
#
# **1.5.1** **theta0 = 0.5, theta1= 0.1**
#
# \[ \]: theta0 = 0.5
#
# theta1 = 0.1
#
# yhat1 = (theta0 + (theta1\*X\[0\]\[0\]))
#
# yhat2 = (theta0 + (theta1\*X\[1\]\[0\]))
#
# yhat3 = (theta0 + (theta1\*X\[2\]\[0\]))
#
# yhat = \[yhat1, yhat2, yhat3\]
#
# yhat
#
# \[ \]: \[10.5, 20.5, 30.5\]
#
# \[ \]: plt.figure(figsize=(5, 5))
#
# plt.grid(color=‘k’, linestyle=’-‘, linewidth=0.5)
#
# plt.scatter(X\[:,0\], Y, color=‘blue’)
#
# plt.plot(X\[:,0\], yhat, ‘-r’)
#
#
#
# 4
#
# plt.xlabel(“size”)
#
# plt.ylabel(“price”)
#
# \[ \]: Text(0, 0.5, ‘price’)
#
#
#
# \[ \]:
#
#
#
# 5
